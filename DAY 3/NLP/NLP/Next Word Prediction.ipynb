# %% [markdown]
# # **N-grams in Language Modeling**

# %% [markdown]
# An **N-gram** is a contiguous sequence of nnn words from a given text or speech corpus. It is widely used in **Natural Language Processing (NLP)** to predict the probability of a word occurring given the preceding words.
#
# ### **How N-grams Work**
#
# *   N-grams capture word sequences and help in probabilistic language modeling.
#
# *   They assume that the probability of a word in a sentence depends only on the previous n−1n-1n−1 words (Markov assumption).
#
# *   This helps in applications such as **speech recognition, text generation, machine translation, and autocomplete features**.
#
#
# #### **N-gram Types**
#
# 1.  **Unigram (n = 1):** Each word is treated independently.
#
#     *   Example: "I", "love", "machine", "learning"
#
# 2.  **Bigram (n = 2):** Probability of a word depends on the previous one.
#
#     *   Example: "I love", "love machine", "machine learning"
#
# 3.  **Trigram (n = 3):** Probability of a word depends on the last two words.
#
#     *   Example: "I love machine", "love machine learning"
#
# 4.  **4-gram, 5-gram, etc.:** Consider longer contexts.
#
#
# ### **Trigram (3-gram) Model**
#
# A **trigram model** uses the previous two words to predict the next word in a sequence.
#
# #### **Example:**
#
# Consider the sentence:
#
# > "I love machine learning."
#
# If we are using a trigram model and have already seen "I love machine", we can predict the most probable next word.
#
# **How does the model predict the next word?**
#
# *   Based on a corpus (large text dataset), the model calculates the probability of possible next words.
#
# *   It uses **Conditional Probability**:
#
#
# If "learning" has the highest probability, the model predicts:
#
# > **"I love machine learning"**
#
# This means:
#
# *   The probability of "learning" following "I love machine" is estimated by counting how often "I love machine learning" appears in a corpus and dividing it by how often "I love machine" appears.
#
#
# ### **Applications of N-gram Models**
#
# 1.  **Speech Recognition:** Predict the most probable next word based on past words.
#
# 2.  **Autocomplete & Text Prediction:** Used in Google search and mobile keyboards.
#
# 3.  **Spelling Correction:** Identifies probable words from misspelled text.
#
# 4.  **Machine Translation:** Helps translate text based on learned word sequences.
#
# 5.  **Sentiment Analysis:** Can capture phrase-based sentiments (e.g., "not very good" vs. "very good").
#
#
# ### **Limitations of N-gram Models**
#
# 1.  **Data Sparsity:** Large datasets are needed to get reliable probabilities.
#
# 2.  **Lack of Long-Term Context:** A trigram model only considers the last two words, ignoring long-range dependencies.
#
# 3.  **High Computational Cost:** Storing probabilities for large n-grams can be memory-intensive.
#
# 4.  **Smoothing Required:** Some word combinations might never appear in the training data, requiring techniques like **Laplace Smoothing** to handle unseen words.

# %%
import nltk
from nltk.util import ngrams
from collections import Counter

# Long sentence as input
text = """
Data science is a rapidly growing field that combines statistics, machine learning, and programming to extract insights from data.
Many companies use data science to improve decision-making, automate processes, and create intelligent systems.
The demand for skilled data scientists continues to increase as more industries recognize the value of data-driven strategies.
"""

# Tokenize text (convert to lowercase for consistency)
words = text.lower().split()

print("Tokenized Words:", words)
# Out:
# Tokenized Words: ['data', 'science', 'is', 'a', 'rapidly', 'growing', 'field', 'that', 'combines', 'statistics,', 'machine', 'learning,', 'and', 'programming', 'to', 'extract', 'insights', 'from', 'data.', 'many', 'companies', 'use', 'data', 'science', 'to', 'improve', 'decision-making,', 'automate', 'processes,', 'and', 'create', 'intelligent', 'systems.', 'the', 'demand', 'for', 'skilled', 'data', 'scientists', 'continues', 'to', 'increase', 'as', 'more', 'industries', 'recognize', 'the', 'value', 'of', 'data-driven', 'strategies.']

# %%
# Generate bigrams (2-grams) and trigrams (3-grams)
bigrams = list(ngrams(words, 2))
trigrams = list(ngrams(words, 3))

print("\nExample Bigrams:")
for bigram in bigrams:
    print(bigram)

print("\nExample Trigrams:")
for trigram in trigrams:
    print(trigram)
# Out:
# Example Bigrams:
# ('data', 'science')
# ('science', 'is')
# ('is', 'a')
# ('a', 'rapidly')
# ('rapidly', 'growing')
# ('growing', 'field')
# ('field', 'that')
# ('that', 'combines')
# ('combines', 'statistics,')
# ('statistics,', 'machine')
# ('machine', 'learning,')
# ('learning,', 'and')
# ('and', 'programming')
# ('programming', 'to')
# ('to', 'extract')
# ('extract', 'insights')
# ('insights', 'from')
# ('from', 'data.')
# ('data.', 'many')
# ('many', 'companies')
# ('companies', 'use')
# ('use', 'data')
# ('data', 'science')
# ('science', 'to')
# ('to', 'improve')
# ('improve', 'decision-making,')
# ('decision-making,', 'automate')
# ('automate', 'processes,')
# ('processes,', 'and')
# ('and', 'create')
# ('create', 'intelligent')
# ('intelligent', 'systems.')
# ('systems.', 'the')
# ('the', 'demand')
# ('demand', 'for')
# ('for', 'skilled')
# ('skilled', 'data')
# ('data', 'scientists')
# ('scientists', 'continues')
# ('continues', 'to')
# ('to', 'increase')
# ('increase', 'as')
# ('as', 'more')
# ('more', 'industries')
# ('industries', 'recognize')
# ('recognize', 'the')
# ('the', 'value')
# ('value', 'of')
# ('of', 'data-driven')
# ('data-driven', 'strategies.')
#
# Example Trigrams:
# ('data', 'science', 'is')
# ('science', 'is', 'a')
# ('is', 'a', 'rapidly')
# ('a', 'rapidly', 'growing')
# ('rapidly', 'growing', 'field')
# ('growing', 'field', 'that')
# ('field', 'that', 'combines')
# ('that', 'combines', 'statistics,')
# ('combines', 'statistics,', 'machine')
# ('statistics,', 'machine', 'learning,')
# ('machine', 'learning,', 'and')
# ('learning,', 'and', 'programming')
# ('and', 'programming', 'to')
# ('programming', 'to', 'extract')
# ('to', 'extract', 'insights')
# ('extract', 'insights', 'from')
# ('insights', 'from', 'data.')
# ('from', 'data.', 'many')
# ('data.', 'many', 'companies')
# ('many', 'companies', 'use')
# ('companies', 'use', 'data')
# ('use', 'data', 'science')
# ('data', 'science', 'to')
# ('science', 'to', 'improve')
# ('to', 'improve', 'decision-making,')
# ('improve', 'decision-making,', 'automate')
# ('decision-making,', 'automate', 'processes,')
# ('automate', 'processes,', 'and')
# ('processes,', 'and', 'create')
# ('and', 'create', 'intelligent')
# ('create', 'intelligent', 'systems.')
# ('intelligent', 'systems.', 'the')
# ('systems.', 'the', 'demand')
# ('the', 'demand', 'for')
# ('demand', 'for', 'skilled')
# ('for', 'skilled', 'data')
# ('skilled', 'data', 'scientists')
# ('data', 'scientists', 'continues')
# ('scientists', 'continues', 'to')
# ('continues', 'to', 'increase')
# ('to', 'increase', 'as')
# ('increase', 'as', 'more')
# ('as', 'more', 'industries')
# ('more', 'industries', 'recognize')
# ('industries', 'recognize', 'the')
# ('recognize', 'the', 'value')
# ('the', 'value', 'of')
# ('value', 'of', 'data-driven')
# ('of', 'data-driven', 'strategies.')

# %%
# Count occurrences of each bigram and trigram
bigram_freq = Counter(bigrams)
trigram_freq = Counter(trigrams)

print("\nMost Common Bigrams:", bigram_freq.most_common(3))
print("\nMost Common Trigrams:", trigram_freq.most_common(3))
# Out:
# Most Common Bigrams: [(('data', 'science'), 2), (('science', 'is'), 1), (('is', 'a'), 1)]
#
# Most Common Trigrams: [(('data', 'science', 'is'), 1), (('science', 'is', 'a'), 1), (('is', 'a', 'rapidly'), 1)]

# %%
def predict_next_word(bigram):
    """Predict the most probable next word given a bigram"""
    possible_trigrams = {trigram: count for trigram, count in trigram_freq.items() if trigram[:2] == bigram}
    
    if not possible_trigrams:
        return None  # No prediction possible
    
    # Return the most frequent next word
    return max(possible_trigrams, key=possible_trigrams.get)[2]

# Test prediction with a bigram
bigram_input = ('science', 'powerful')  # Example bigram
predicted_word = predict_next_word(bigram_input)

print(f"\nGiven Bigram: {bigram_input}")
print(f"Predicted Next Word: {predicted_word}")
# Out:
# Given Bigram: ('science', 'powerful')
# Predicted Next Word: None

# %%
def predict_next_word(word):
    """Predict the most probable next word given a single word (unigram)"""
    possible_bigrams = {bigram: count for bigram, count in bigram_freq.items() if bigram[0] == word}
    
    if not possible_bigrams:
        return None  # No prediction possible
    
    # Return the most frequent next word
    return max(possible_bigrams, key=possible_bigrams.get)[1]

# Test prediction
input_word = 'growing'  # Example unigram
predicted_word = predict_next_word(input_word)

print(f"\nGiven Word: {input_word}")
print(f"Predicted Next Word: {predicted_word}")
# Out:
# Given Word: growing
# Predicted Next Word: field

# %% [markdown]
# **Advantages of N-grams**
# -------------------------
#
# ✅ **Simple & Fast**
#
# ✅ **Works Well for Small Datasets**
#
# **Limitations of N-grams**
#
# --------------------------
#
# ❌ **No Long-Term Context** (Only considers limited previous words)
#
# ❌ **Data Sparsity** (Rare sequences are hard to predict)
#
# ❌ **Fixed Window** (N-gram size limits the model's ability to learn complex patterns)

# %% [markdown]
# ## 1. Importing Libraries
#
# - `tensorflow.keras.models.Sequential`: Defines a sequential neural network model where layers are added one after another.
# - `tensorflow.keras.layers.Embedding`: Converts words into dense vector representations (word embeddings) that capture semantic meaning.
# - `tensorflow.keras.layers.LSTM`: A type of recurrent neural network (RNN) used for processing sequential data, capable of learning long-term dependencies.
# - `tensorflow.keras.layers.Dense`: Fully connected layer that applies transformations to the input.
# - `tensorflow.keras.preprocessing.text.Tokenizer`: Tokenizes (splits) text into individual words or subwords and converts them into numerical values.
# - `tensorflow.keras.preprocessing.sequence.pad_sequences`: Ensures that all sequences have the same length by padding shorter sequences.
# - `numpy`: Used for numerical computations.
# - `regex`: A library for handling advanced regular expressions, which can be used for text preprocessing.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import regex as re

# %% [markdown]
# # **Text Tokenization and N-gram Sequence Generation in TensorFlow**
#
# This section explains how to preprocess a text file into structured data for training an **LSTM-based language model**. The process includes **text tokenization, n-gram sequence creation, padding, and target encoding**.
#
# ---
#
# ## **1. Reading and Splitting the Text File**
#
# ### **Function: `file_to_sentence_list(file_path)`**
# - Opens the text file and reads its content.
# - Splits the text into **sentences** using delimiters like `.` (period), `?` (question mark), and `!` (exclamation mark).
# - Uses **regular expressions (`regex`)** to ensure sentences are correctly identified.
# - Returns a **list of cleaned sentences**.
#
# ---
#
# ## **2. Tokenization**
#
# ### **Using `Tokenizer` from Keras**
# - The **Tokenizer** converts sentences into numerical sequences.
# - It assigns a **unique integer** to each word in the text.
# - The `word_index` dictionary stores the mapping of words to integers.
# - The `total_words` variable represents the vocabulary size (number of unique words + 1 for padding).
#
# ---
#
# ## **3. Generating Input Sequences (N-grams)**
#
# ### **Steps:**
# - Iterate through each sentence.
# - Convert the sentence into a sequence of word indices.
# - Generate **n-gram sequences** by progressively adding words.
#
# **Example:**
# For a sentence `"I love pizza"`:
# - Tokens: `[1, 2, 3]`
# - Generated sequences:
#   - `[1, 2]`
#   - `[1, 2, 3]`
#
# Each sequence helps the model learn contextual word predictions.
#
# ---
#
# ## **4. Padding Sequences and Splitting Data**
#
# - Sentences vary in length, so we **pad sequences** to make them uniform.
# - `pad_sequences()` ensures that all sequences have the **same length** by adding zeros at the beginning (`padding='pre'`).
# - The **maximum sequence length** (`max_sequence_len`) is determined by the longest n-gram.
# - The dataset is split into:
#   - `X`: **Predictors** (all but the last word in the sequence).
#   - `y`: **Labels** (the last word in the sequence).
#
# ---
#
# ## **5. Converting Targets to One-Hot Encoding**
#
# - The output `y` needs to be **categorical**, representing words as probability distributions.
# - `tf.keras.utils.to_categorical()` converts numerical labels into a **one-hot encoded format**.
# - The number of classes is set to `total_words` (the vocabulary size).
#
# ---
#
# ## **Final Output**
# At the end of this preprocessing pipeline, we have:
# - **`X`**: A matrix of padded n-gram sequences.
# - **`y`**: One-hot encoded target words.
# - This structured data is ready for training an **LSTM-based language model**.

# %%
def file_to_sentence_list(file_path):
    with open(file_path, 'r') as file:
        text = file.read()

    # Splitting the text into sentences using
    # delimiters like '.', '?', and '!'
    sentences = [sentence.strip() for sentence in re.split(
        r'(?<=[.!?])\s+', text) if sentence.strip()]

    return sentences

file_path = 'pizza.txt'
text_data = file_to_sentence_list(file_path)

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_data)
total_words = len(tokenizer.word_index) + 1

"""

Converts each sentence into a list of tokenized words.
Creates n-gram sequences:
Iterates through each tokenized sentence.
For each tokenized word, generates an incremental sequence.
Appends it to input_sequences.

"""
input_sequences = []
for line in text_data:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

""""
Finds the maximum sequence length in input_sequences.
Pads sequences to make them the same length:
Uses pad_sequences() from Keras.
padding='pre' ensures shorter sequences are padded at the beginning.
Splits input_sequences into features (X) and labels (y):
X → All tokens except the last ([:, :-1]).
y → The last token in the sequence ([:, -1]).
"""

# Pad sequences and split into predictors and label

"""
Why Do We Use Padding?
When training deep learning models, especially Recurrent Neural Networks (RNNs),
Long Short-Term Memory (LSTMs),and Transformers, all input sequences must have the same length because:
"""
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array(pad_sequences(
    input_sequences, maxlen=max_sequence_len, padding='pre'))
X, y = input_sequences[:, :-1], input_sequences[:, -1]

# Convert target data to one-hot encoding
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %% [markdown]
#  # **Building an LSTM-based Language Model with TensorFlow**
#
#  In this section, we define and compile a **Sequential LSTM model** for text generation or next-word prediction.  ---
#
#  ## **1. Model Architecture**
#
#  ### **1.1 Embedding Layer**
#
#  model.add(Embedding(total_words, 10, input_length=max_sequence_len-1))   `
#
# *   **Purpose**: Converts integer-encoded words into dense vector representations.
#
# *   total\_words: Vocabulary size (number of unique words).
#
# *   10: The size of the embedding vector (each word is represented by a 10-dimensional vector).
#
# *   input\_length=max\_sequence\_len-1: The input length (one less than the maximum sequence length).
#
#
# ### **1.2 LSTM Layer**
# model.add(LSTM(128))   `
#
# *   **Purpose**: Captures sequential dependencies in text data.
#
# *   128: Number of LSTM units (neurons) that process the sequential data.
#
# *   Uses **Long Short-Term Memory (LSTM)** to remember long-term dependencies in the text.
#
#
# ### **1.3 Dense (Output) Layer**
# model.add(Dense(total_words, activation='softmax'))   `
#
# *   **Purpose**: Produces the probability distribution over all possible next words.
#
# *   total\_words: The number of unique words (vocabulary size).
#
# *   activation='softmax': Ensures that the model outputs probabilities, making it suitable for multi-class classification.
#
#
# **2\. Model Compilation**
# -------------------------
#
# model.compile(loss='categorical_crossentropy',                optimizer='adam', metrics=['accuracy'])   `
#
# *   **Loss Function**: categorical\_crossentropy
#
#     *   Used for multi-class classification.
#
#     *   Measures how well the model predicts the next word.
#
# *   **Optimizer**: adam
#
#     *   Adaptive learning rate optimization algorithm.
#
# *   **Metric**: accuracy
#
#     *   Used to measure the proportion of correctly predicted words.
#
#
# **Summary**
# -----------
#
# *   The model takes a sequence of words as input.
#
# *   The **Embedding Layer** converts words into dense vectors.
#
# *   The **LSTM Layer** captures contextual dependencies.
#
# *   The **Dense Layer** predicts the next word.
#
# *   The model is compiled with categorical crossentropy loss and the Adam optimizer.

# %%
# Define the model
model = Sequential()
model.add(Embedding(total_words, 10,
                    input_length=max_sequence_len-1))
model.add(LSTM(128))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
model.fit(X, y, epochs=500, verbose=1)
# Out:
# Epoch 1/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9605 - loss: 0.1368
# Epoch 2/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9611 - loss: 0.1303
# Epoch 3/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9649 - loss: 0.1198
# Epoch 4/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9728 - loss: 0.1066
# Epoch 5/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9660 - loss: 0.1266
# Epoch 6/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9567 - loss: 0.1388
# Epoch 7/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9611 - loss: 0.1303
# Epoch 8/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9729 - loss: 0.1158
# Epoch 9/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9666 - loss: 0.1225
# Epoch 10/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9726 - loss: 0.1062
# Epoch 11/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9683 - loss: 0.1185
# Epoch 12/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9766 - loss: 0.0934
# Epoch 13/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9686 - loss: 0.1157
# Epoch 14/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9651 - loss: 0.1176
# Epoch 15/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9622 - loss: 0.1228
# Epoch 16/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9714 - loss: 0.1101
# Epoch 17/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9652 - loss: 0.1051
# Epoch 18/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9687 - loss: 0.1059
# Epoch 19/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9693 - loss: 0.1060
# Epoch 20/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9674 - loss: 0.0988
# Epoch 21/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9695 - loss: 0.1117
# Epoch 22/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9678 - loss: 0.1076
# Epoch 23/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9708 - loss: 0.1144
# Epoch 24/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9763 - loss: 0.0943
# Epoch 25/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9765 - loss: 0.0921
# Epoch 26/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9655 - loss: 0.1213
# Epoch 27/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9676 - loss: 0.1052
# Epoch 28/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9691 - loss: 0.0987
# Epoch 29/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9657 - loss: 0.1120
# Epoch 30/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9749 - loss: 0.0974
# Epoch 31/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9658 - loss: 0.1048
# Epoch 32/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9679 - loss: 0.1009
# Epoch 33/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9698 - loss: 0.0901
# Epoch 34/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9714 - loss: 0.0898
# Epoch 35/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9738 - loss: 0.0879
# Epoch 36/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9680 - loss: 0.1074
# Epoch 37/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9692 - loss: 0.0916
# Epoch 38/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9719 - loss: 0.0992
# Epoch 39/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9602 - loss: 0.1157
# Epoch 40/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9662 - loss: 0.0974
# Epoch 41/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9750 - loss: 0.0866
# Epoch 42/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9683 - loss: 0.0950
# Epoch 43/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9670 - loss: 0.1001
# Epoch 44/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9686 - loss: 0.0950
# Epoch 45/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9719 - loss: 0.0897
# Epoch 46/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9744 - loss: 0.0944
# Epoch 47/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9618 - loss: 0.1105
# Epoch 48/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9709 - loss: 0.0879
# Epoch 49/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9692 - loss: 0.0939
# Epoch 50/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9750 - loss: 0.0815
# Epoch 51/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9699 - loss: 0.0813
# Epoch 52/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9777 - loss: 0.0759
# Epoch 53/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9677 - loss: 0.0852
# Epoch 54/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9701 - loss: 0.0851
# Epoch 55/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9701 - loss: 0.0840
# Epoch 56/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9638 - loss: 0.0987
# Epoch 57/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9652 - loss: 0.0838
# Epoch 58/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9701 - loss: 0.0844
# Epoch 59/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9753 - loss: 0.0829
# Epoch 60/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9721 - loss: 0.0874
# Epoch 61/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9667 - loss: 0.0888
# Epoch 62/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9694 - loss: 0.0823
# Epoch 63/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9653 - loss: 0.1158
# Epoch 64/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9307 - loss: 0.2528
# Epoch 65/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9676 - loss: 0.1150
# Epoch 66/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9682 - loss: 0.0931
# Epoch 67/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9724 - loss: 0.0842
# Epoch 68/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9648 - loss: 0.0884
# Epoch 69/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9711 - loss: 0.0871
# Epoch 70/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9692 - loss: 0.0793
# Epoch 71/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9694 - loss: 0.0795
# Epoch 72/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9791 - loss: 0.0720
# Epoch 73/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9715 - loss: 0.0782
# Epoch 74/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9668 - loss: 0.0850
# Epoch 75/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9722 - loss: 0.0710
# Epoch 76/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9715 - loss: 0.0817
# Epoch 77/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9702 - loss: 0.0864
# Epoch 78/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9684 - loss: 0.0817
# Epoch 79/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9731 - loss: 0.0735
# Epoch 80/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9607 - loss: 0.0868
# Epoch 81/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9703 - loss: 0.0737
# Epoch 82/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9748 - loss: 0.0661
# Epoch 83/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9710 - loss: 0.0818
# Epoch 84/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9745 - loss: 0.0818
# Epoch 85/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9757 - loss: 0.0680
# Epoch 86/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9822 - loss: 0.0603
# Epoch 87/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9715 - loss: 0.0721
# Epoch 88/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9659 - loss: 0.0737
# Epoch 89/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9756 - loss: 0.0685
# Epoch 90/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9682 - loss: 0.0906
# Epoch 91/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9630 - loss: 0.0908
# Epoch 92/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9671 - loss: 0.0773
# Epoch 93/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9763 - loss: 0.0640
# Epoch 94/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9748 - loss: 0.0676
# Epoch 95/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9749 - loss: 0.0763
# Epoch 96/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9750 - loss: 0.0662
# Epoch 97/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9700 - loss: 0.0866
# Epoch 98/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9690 - loss: 0.0863
# Epoch 99/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9700 - loss: 0.0736
# Epoch 100/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9761 - loss: 0.0766
# Epoch 101/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9727 - loss: 0.0711
# Epoch 102/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9655 - loss: 0.0826
# Epoch 103/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9717 - loss: 0.0719
# Epoch 104/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9661 - loss: 0.0875
# Epoch 105/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9631 - loss: 0.0929
# Epoch 106/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9729 - loss: 0.0670
# Epoch 107/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9733 - loss: 0.0700
# Epoch 108/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9696 - loss: 0.0777
# Epoch 109/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9698 - loss: 0.0831
# Epoch 110/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9693 - loss: 0.0709
# Epoch 111/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9734 - loss: 0.0692
# Epoch 112/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9720 - loss: 0.0680
# Epoch 113/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9681 - loss: 0.0712
# Epoch 114/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9705 - loss: 0.0708
# Epoch 115/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9656 - loss: 0.0808
# Epoch 116/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9584 - loss: 0.0771
# Epoch 117/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9680 - loss: 0.0802
# Epoch 118/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9732 - loss: 0.0652
# Epoch 119/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9712 - loss: 0.0731
# Epoch 120/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9722 - loss: 0.0715
# Epoch 121/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9739 - loss: 0.0672
# Epoch 122/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9724 - loss: 0.0590
# Epoch 123/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9753 - loss: 0.0652
# Epoch 124/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9667 - loss: 0.0794
# Epoch 125/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9655 - loss: 0.0791
# Epoch 126/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9758 - loss: 0.0604
# Epoch 127/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9705 - loss: 0.0738
# Epoch 128/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9751 - loss: 0.0567
# Epoch 129/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9720 - loss: 0.0759
# Epoch 130/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9697 - loss: 0.0714
# Epoch 131/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9700 - loss: 0.0688
# Epoch 132/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9653 - loss: 0.0817
# Epoch 133/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9718 - loss: 0.0667
# Epoch 134/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9711 - loss: 0.0674
# Epoch 135/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9634 - loss: 0.0887
# Epoch 136/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9712 - loss: 0.0684
# Epoch 137/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9647 - loss: 0.0812
# Epoch 138/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9663 - loss: 0.0774
# Epoch 139/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9674 - loss: 0.0811
# Epoch 140/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9679 - loss: 0.0778
# Epoch 141/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9719 - loss: 0.0676
# Epoch 142/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9695 - loss: 0.0742
# Epoch 143/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9750 - loss: 0.0578
# Epoch 144/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9675 - loss: 0.0635
# Epoch 145/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9666 - loss: 0.0765
# Epoch 146/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9771 - loss: 0.0623
# Epoch 147/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9667 - loss: 0.0758
# Epoch 148/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9738 - loss: 0.0682
# Epoch 149/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9804 - loss: 0.0554
# Epoch 150/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9800 - loss: 0.0488
# Epoch 151/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9697 - loss: 0.0616
# Epoch 152/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9631 - loss: 0.0819
# Epoch 153/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9680 - loss: 0.0741
# Epoch 154/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9706 - loss: 0.0669
# Epoch 155/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9771 - loss: 0.0528
# Epoch 156/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9708 - loss: 0.0763
# Epoch 157/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9703 - loss: 0.0619
# Epoch 158/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9756 - loss: 0.0548
# Epoch 159/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9698 - loss: 0.0684
# Epoch 160/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9729 - loss: 0.0584
# Epoch 161/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9664 - loss: 0.0799
# Epoch 162/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9728 - loss: 0.0645
# Epoch 163/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9652 - loss: 0.0884
# Epoch 164/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9730 - loss: 0.0667
# Epoch 165/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9678 - loss: 0.0685
# Epoch 166/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9730 - loss: 0.0658
# Epoch 167/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9693 - loss: 0.0770
# Epoch 168/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9755 - loss: 0.0542
# Epoch 169/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9755 - loss: 0.0589
# Epoch 170/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9714 - loss: 0.0620
# Epoch 171/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9747 - loss: 0.0554
# Epoch 172/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9674 - loss: 0.0694
# Epoch 173/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9656 - loss: 0.0740
# Epoch 174/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9804 - loss: 0.0475
# Epoch 175/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9617 - loss: 0.0791
# Epoch 176/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9740 - loss: 0.0707
# Epoch 177/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9672 - loss: 0.0706
# Epoch 178/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9614 - loss: 0.0760
# Epoch 179/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9711 - loss: 0.0644
# Epoch 180/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9703 - loss: 0.0679
# Epoch 181/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9735 - loss: 0.0614
# Epoch 182/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9682 - loss: 0.0642
# Epoch 183/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9734 - loss: 0.0650
# Epoch 184/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9752 - loss: 0.0647
# Epoch 185/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9739 - loss: 0.0664
# Epoch 186/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9756 - loss: 0.0584
# Epoch 187/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9636 - loss: 0.0727
# Epoch 188/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9617 - loss: 0.0753
# Epoch 189/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9700 - loss: 0.0647
# Epoch 190/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9747 - loss: 0.0620
# Epoch 191/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9685 - loss: 0.0697
# Epoch 192/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9698 - loss: 0.0748
# Epoch 193/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9706 - loss: 0.0727
# Epoch 194/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9591 - loss: 0.0914
# Epoch 195/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9721 - loss: 0.0631
# Epoch 196/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9670 - loss: 0.0707
# Epoch 197/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9710 - loss: 0.0652
# Epoch 198/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9633 - loss: 0.0833
# Epoch 199/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9698 - loss: 0.0698
# Epoch 200/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9705 - loss: 0.0684
# Epoch 201/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9698 - loss: 0.0613
# Epoch 202/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9749 - loss: 0.0611
# Epoch 203/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9735 - loss: 0.0595
# Epoch 204/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9679 - loss: 0.0787
# Epoch 205/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9681 - loss: 0.0677
# Epoch 206/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9730 - loss: 0.0639
# Epoch 207/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9707 - loss: 0.0564
# Epoch 208/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9699 - loss: 0.0672
# Epoch 209/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9708 - loss: 0.0593
# Epoch 210/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9660 - loss: 0.0676
# Epoch 211/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9692 - loss: 0.0592
# Epoch 212/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9751 - loss: 0.0573
# Epoch 213/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9448 - loss: 0.1759
# Epoch 214/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9491 - loss: 0.1404
# Epoch 215/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9748 - loss: 0.0681
# Epoch 216/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9709 - loss: 0.0647
# Epoch 217/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9678 - loss: 0.0634
# Epoch 218/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9729 - loss: 0.0666
# Epoch 219/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9730 - loss: 0.0632
# Epoch 220/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9725 - loss: 0.0631
# Epoch 221/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9598 - loss: 0.0893
# Epoch 222/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9696 - loss: 0.0728
# Epoch 223/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9650 - loss: 0.0774
# Epoch 224/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9759 - loss: 0.0605
# Epoch 225/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9650 - loss: 0.0716
# Epoch 226/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9614 - loss: 0.0875
# Epoch 227/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9661 - loss: 0.0806
# Epoch 228/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9724 - loss: 0.0692
# Epoch 229/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9762 - loss: 0.0625
# Epoch 230/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9741 - loss: 0.0658
# Epoch 231/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9754 - loss: 0.0542
# Epoch 232/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9764 - loss: 0.0635
# Epoch 233/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9635 - loss: 0.0843
# Epoch 234/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9722 - loss: 0.0633
# Epoch 235/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9698 - loss: 0.0664
# Epoch 236/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9737 - loss: 0.0566
# Epoch 237/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9749 - loss: 0.0563
# Epoch 238/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9694 - loss: 0.0742
# Epoch 239/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9768 - loss: 0.0546
# Epoch 240/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9688 - loss: 0.0620
# Epoch 241/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9717 - loss: 0.0584
# Epoch 242/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9786 - loss: 0.0587
# Epoch 243/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9700 - loss: 0.0647
# Epoch 244/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9724 - loss: 0.0612
# Epoch 245/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9647 - loss: 0.0766
# Epoch 246/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9703 - loss: 0.0692
# Epoch 247/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9753 - loss: 0.0626
# Epoch 248/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9740 - loss: 0.0601
# Epoch 249/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9728 - loss: 0.0569
# Epoch 250/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9687 - loss: 0.0696
# Epoch 251/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9770 - loss: 0.0567
# Epoch 252/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9636 - loss: 0.0824
# Epoch 253/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9721 - loss: 0.0675
# Epoch 254/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9721 - loss: 0.0642
# Epoch 255/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9722 - loss: 0.0661
# Epoch 256/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9626 - loss: 0.0822
# Epoch 257/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9708 - loss: 0.0723
# Epoch 258/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9654 - loss: 0.0652
# Epoch 259/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9700 - loss: 0.0621
# Epoch 260/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9731 - loss: 0.0680
# Epoch 261/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9676 - loss: 0.0698
# Epoch 262/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9712 - loss: 0.0667
# Epoch 263/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9732 - loss: 0.0666
# Epoch 264/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9630 - loss: 0.0754
# Epoch 265/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9630 - loss: 0.0782
# Epoch 266/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9666 - loss: 0.0696
# Epoch 267/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9603 - loss: 0.0761
# Epoch 268/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9754 - loss: 0.0642
# Epoch 269/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9701 - loss: 0.0723
# Epoch 270/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9767 - loss: 0.0570
# Epoch 271/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9777 - loss: 0.0582
# Epoch 272/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9751 - loss: 0.0540
# Epoch 273/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9681 - loss: 0.0746
# Epoch 274/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9667 - loss: 0.0663
# Epoch 275/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9711 - loss: 0.0617
# Epoch 276/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9653 - loss: 0.0667
# Epoch 277/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9599 - loss: 0.0870
# Epoch 278/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9686 - loss: 0.0657
# Epoch 279/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9691 - loss: 0.0643
# Epoch 280/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9730 - loss: 0.0599
# Epoch 281/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9680 - loss: 0.0712
# Epoch 282/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9564 - loss: 0.0895
# Epoch 283/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9745 - loss: 0.0555
# Epoch 284/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9716 - loss: 0.0625
# Epoch 285/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9732 - loss: 0.0573
# Epoch 286/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9724 - loss: 0.0622
# Epoch 287/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9740 - loss: 0.0591
# Epoch 288/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9741 - loss: 0.0557
# Epoch 289/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9726 - loss: 0.0625
# Epoch 290/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9679 - loss: 0.0692
# Epoch 291/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9742 - loss: 0.0645
# Epoch 292/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9724 - loss: 0.0609
# Epoch 293/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9727 - loss: 0.0673
# Epoch 294/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9774 - loss: 0.0527
# Epoch 295/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9721 - loss: 0.0647
# Epoch 296/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9707 - loss: 0.0649
# Epoch 297/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9645 - loss: 0.0685
# Epoch 298/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9676 - loss: 0.0702
# Epoch 299/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9740 - loss: 0.0637
# Epoch 300/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9758 - loss: 0.0600
# Epoch 301/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9697 - loss: 0.0725
# Epoch 302/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9732 - loss: 0.0597
# Epoch 303/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9733 - loss: 0.0605
# Epoch 304/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9714 - loss: 0.0634
# Epoch 305/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9635 - loss: 0.0828
# Epoch 306/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9680 - loss: 0.0749
# Epoch 307/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9702 - loss: 0.0647
# Epoch 308/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9722 - loss: 0.0685
# Epoch 309/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9732 - loss: 0.0549
# Epoch 310/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9646 - loss: 0.0678
# Epoch 311/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9686 - loss: 0.0716
# Epoch 312/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9680 - loss: 0.0696
# Epoch 313/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9712 - loss: 0.0674
# Epoch 314/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9656 - loss: 0.0741
# Epoch 315/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9741 - loss: 0.0638
# Epoch 316/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9686 - loss: 0.0719
# Epoch 317/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9693 - loss: 0.0663
# Epoch 318/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9786 - loss: 0.0571
# Epoch 319/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9753 - loss: 0.0597
# Epoch 320/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9702 - loss: 0.0628
# Epoch 321/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9795 - loss: 0.0533
# Epoch 322/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9704 - loss: 0.0688
# Epoch 323/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9707 - loss: 0.0741
# Epoch 324/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9662 - loss: 0.0623
# Epoch 325/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9658 - loss: 0.0760
# Epoch 326/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9745 - loss: 0.0624
# Epoch 327/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9735 - loss: 0.0639
# Epoch 328/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9678 - loss: 0.0742
# Epoch 329/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9746 - loss: 0.0629
# Epoch 330/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9715 - loss: 0.0618
# Epoch 331/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9679 - loss: 0.0710
# Epoch 332/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9749 - loss: 0.0564
# Epoch 333/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9696 - loss: 0.0606
# Epoch 334/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9709 - loss: 0.0634
# Epoch 335/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9778 - loss: 0.0587
# Epoch 336/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9690 - loss: 0.0666
# Epoch 337/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9689 - loss: 0.0683
# Epoch 338/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9784 - loss: 0.0558
# Epoch 339/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9786 - loss: 0.0470
# Epoch 340/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9768 - loss: 0.0589
# Epoch 341/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9681 - loss: 0.0718
# Epoch 342/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9693 - loss: 0.0567
# Epoch 343/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9747 - loss: 0.0659
# Epoch 344/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9699 - loss: 0.0694
# Epoch 345/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9730 - loss: 0.0607
# Epoch 346/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9727 - loss: 0.0636
# Epoch 347/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9726 - loss: 0.0605
# Epoch 348/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9681 - loss: 0.0674
# Epoch 349/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9746 - loss: 0.0690
# Epoch 350/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9750 - loss: 0.0618
# Epoch 351/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9727 - loss: 0.0638
# Epoch 352/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9654 - loss: 0.0704
# Epoch 353/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9732 - loss: 0.0604
# Epoch 354/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9780 - loss: 0.0509
# Epoch 355/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9691 - loss: 0.0710
# Epoch 356/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9734 - loss: 0.0575
# Epoch 357/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9636 - loss: 0.0812
# Epoch 358/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9786 - loss: 0.0462
# Epoch 359/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9694 - loss: 0.0673
# Epoch 360/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9720 - loss: 0.0545
# Epoch 361/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9693 - loss: 0.0708
# Epoch 362/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9685 - loss: 0.0682
# Epoch 363/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9693 - loss: 0.0643
# Epoch 364/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9649 - loss: 0.0662
# Epoch 365/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9711 - loss: 0.0671
# Epoch 366/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9716 - loss: 0.0564
# Epoch 367/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9701 - loss: 0.0640
# Epoch 368/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9738 - loss: 0.0626
# Epoch 369/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9699 - loss: 0.0707
# Epoch 370/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9764 - loss: 0.0561
# Epoch 371/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9699 - loss: 0.0670
# Epoch 372/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9710 - loss: 0.0645
# Epoch 373/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9682 - loss: 0.0675
# Epoch 374/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9672 - loss: 0.0633
# Epoch 375/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9691 - loss: 0.0563
# Epoch 376/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9698 - loss: 0.0691
# Epoch 377/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9658 - loss: 0.0789
# Epoch 378/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9694 - loss: 0.0688
# Epoch 379/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9759 - loss: 0.0554
# Epoch 380/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9640 - loss: 0.0762
# Epoch 381/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9722 - loss: 0.0645
# Epoch 382/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9681 - loss: 0.0703
# Epoch 383/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9627 - loss: 0.0798
# Epoch 384/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9693 - loss: 0.0591
# Epoch 385/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9680 - loss: 0.0686
# Epoch 386/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9734 - loss: 0.0643
# Epoch 387/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9733 - loss: 0.0545
# Epoch 388/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9743 - loss: 0.0572
# Epoch 389/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9649 - loss: 0.0628
# Epoch 390/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9678 - loss: 0.0598
# Epoch 391/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9783 - loss: 0.0577
# Epoch 392/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9689 - loss: 0.0692
# Epoch 393/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9653 - loss: 0.0677
# Epoch 394/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9707 - loss: 0.0556
# Epoch 395/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9744 - loss: 0.0593
# Epoch 396/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9760 - loss: 0.0559
# Epoch 397/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9683 - loss: 0.0655
# Epoch 398/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9756 - loss: 0.0538
# Epoch 399/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9620 - loss: 0.0746
# Epoch 400/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9714 - loss: 0.0676
# Epoch 401/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9724 - loss: 0.0664
# Epoch 402/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9692 - loss: 0.0645
# Epoch 403/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9798 - loss: 0.0505
# Epoch 404/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9732 - loss: 0.0636
# Epoch 405/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9762 - loss: 0.0497
# Epoch 406/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9783 - loss: 0.0558
# Epoch 407/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9731 - loss: 0.0574
# Epoch 408/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9490 - loss: 0.1538
# Epoch 409/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9426 - loss: 0.1531
# Epoch 410/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9696 - loss: 0.0709
# Epoch 411/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9684 - loss: 0.0679
# Epoch 412/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9640 - loss: 0.0737
# Epoch 413/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9695 - loss: 0.0665
# Epoch 414/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9715 - loss: 0.0605
# Epoch 415/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9692 - loss: 0.0654
# Epoch 416/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9728 - loss: 0.0676
# Epoch 417/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9680 - loss: 0.0642
# Epoch 418/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9688 - loss: 0.0731
# Epoch 419/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9635 - loss: 0.0805
# Epoch 420/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9648 - loss: 0.0740
# Epoch 421/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9710 - loss: 0.0660
# Epoch 422/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9696 - loss: 0.0640
# Epoch 423/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9635 - loss: 0.0816
# Epoch 424/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9712 - loss: 0.0669
# Epoch 425/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9752 - loss: 0.0596
# Epoch 426/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9723 - loss: 0.0660
# Epoch 427/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9599 - loss: 0.0785
# Epoch 428/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9753 - loss: 0.0597
# Epoch 429/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9758 - loss: 0.0589
# Epoch 430/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9723 - loss: 0.0580
# Epoch 431/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9685 - loss: 0.0632
# Epoch 432/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9691 - loss: 0.0691
# Epoch 433/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9630 - loss: 0.0739
# Epoch 434/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9694 - loss: 0.0583
# Epoch 435/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9734 - loss: 0.0508
# Epoch 436/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9766 - loss: 0.0550
# Epoch 437/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9625 - loss: 0.0778
# Epoch 438/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9750 - loss: 0.0593
# Epoch 439/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9735 - loss: 0.0603
# Epoch 440/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9725 - loss: 0.0637
# Epoch 441/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9734 - loss: 0.0605
# Epoch 442/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9704 - loss: 0.0759
# Epoch 443/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9734 - loss: 0.0641
# Epoch 444/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9659 - loss: 0.0674
# Epoch 445/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9735 - loss: 0.0621
# Epoch 446/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9621 - loss: 0.0691
# Epoch 447/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9688 - loss: 0.0692
# Epoch 448/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9745 - loss: 0.0567
# Epoch 449/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9678 - loss: 0.0694
# Epoch 450/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9718 - loss: 0.0632
# Epoch 451/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9691 - loss: 0.0618
# Epoch 452/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9751 - loss: 0.0619
# Epoch 453/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9735 - loss: 0.0638
# Epoch 454/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9657 - loss: 0.0733
# Epoch 455/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9726 - loss: 0.0576
# Epoch 456/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9669 - loss: 0.0706
# Epoch 457/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9727 - loss: 0.0640
# Epoch 458/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9617 - loss: 0.0739
# Epoch 459/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9695 - loss: 0.0609
# Epoch 460/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9743 - loss: 0.0558
# Epoch 461/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9778 - loss: 0.0591
# Epoch 462/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9754 - loss: 0.0576
# Epoch 463/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9651 - loss: 0.0750
# Epoch 464/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9776 - loss: 0.0548
# Epoch 465/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9751 - loss: 0.0555
# Epoch 466/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9669 - loss: 0.0609
# Epoch 467/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9707 - loss: 0.0663
# Epoch 468/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9731 - loss: 0.0605
# Epoch 469/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9641 - loss: 0.0721
# Epoch 470/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9713 - loss: 0.0667
# Epoch 471/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9692 - loss: 0.0710
# Epoch 472/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9703 - loss: 0.0658
# Epoch 473/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9680 - loss: 0.0681
# Epoch 474/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9730 - loss: 0.0683
# Epoch 475/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9659 - loss: 0.0735
# Epoch 476/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9672 - loss: 0.0641
# Epoch 477/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9779 - loss: 0.0558
# Epoch 478/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9691 - loss: 0.0636
# Epoch 479/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9746 - loss: 0.0530
# Epoch 480/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9697 - loss: 0.0692
# Epoch 481/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9715 - loss: 0.0663
# Epoch 482/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9726 - loss: 0.0623
# Epoch 483/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9763 - loss: 0.0549
# Epoch 484/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9798 - loss: 0.0600
# Epoch 485/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9726 - loss: 0.0600
# Epoch 486/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9778 - loss: 0.0613
# Epoch 487/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9692 - loss: 0.0624
# Epoch 488/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9689 - loss: 0.0684
# Epoch 489/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9720 - loss: 0.0659
# Epoch 490/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9679 - loss: 0.0655
# Epoch 491/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9711 - loss: 0.0588
# Epoch 492/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9713 - loss: 0.0647
# Epoch 493/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9640 - loss: 0.0707
# Epoch 494/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9764 - loss: 0.0508
# Epoch 495/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9716 - loss: 0.0598
# Epoch 496/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9728 - loss: 0.0607
# Epoch 497/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9656 - loss: 0.0743
# Epoch 498/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9709 - loss: 0.0684
# Epoch 499/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9705 - loss: 0.0625
# Epoch 500/500
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9699 - loss: 0.0669

# %% [markdown]
#  # **Generating Next Word Predictions with the LSTM Model**
#
#  This section describes how to generate **next-word predictions** using the trained LSTM model.
#
# ## **1. Input Seed Text**  seed_text = "i like "  next_words = 10   `
#
# *   The seed\_text is the **starting phrase** for prediction.
#
# *   next\_words = 10 specifies the number of words to generate.
#
#
# **2\. Word Tokenization & Padding**
# -----------------------------------
#   tokenizer.texts_to_sequences([seed_text])[0]
#
#   token_list = pad_sequences([token_list],
#
#   maxlen=max_sequence_len-1, padding='pre')   `
#
# *   The Tokenizer converts the seed\_text into a numerical sequence.
#
# *   Since LSTM models require **fixed-length inputs**, pad\_sequences() ensures uniform input size.
#
# *   padding='pre' pads the sequence at the beginning with zeros.
#
#
# **3\. Predicting the Next Word**
# --------------------------------
# predicted_probs = model.predict(token_list)
# predicted_word = tokenizer.index_word[np.argmax(predicted_probs)]   `
#
# *   **Model Prediction**:
#
#     *   The LSTM model predicts the **probability distribution** over all words in the vocabulary.
#
#     *   The output is a **softmax probability array**, where each value represents the likelihood of a word being the next word.
#
# *   **Selecting the Next Word**:
#
#     *   np.argmax(predicted\_probs): Finds the index of the word with the highest probability.
#
#     *   tokenizer.index\_word\[\]: Converts the index back to the actual word.
#
#
# **4\. Iterative Word Generation**
# ---------------------------------
#  seed_text += " " + predicted_word   `
#
# *   The predicted word is appended to seed\_text, allowing the model to generate **longer sequences**.
#
# *   The loop continues for next\_words iterations, generating a sentence word by word.
#
#
# **5\. Output**
# --------------
# print("Next predicted words:", seed_text)   `
#
# *   Displays the **generated sentence** after next\_words iterations.

# %%
# Generate next word predictions
seed_text = "i like "
next_words = 10

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences(
        [token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted_probs = model.predict(token_list)
    predicted_word = tokenizer.index_word[np.argmax(predicted_probs)]
    seed_text += " " + predicted_word

print("Next predicted words:", seed_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Next predicted words: i like  its soft and chewy neapolitan crust topped with the perfect
