# %%
import google.generativeai as genai

api_key = "AIzaSyBuTzbFHsQnyw_wO2pmlPwDQ_Ha7ys2qxE" 
genai.configure(api_key=api_key)

model = genai.GenerativeModel("gemini-1.5-flash")
user_input = input("Ask any question: ")
response = model.generate_content(user_input) 
print(response.text)
# Out:
# The current Prime Minister of India is Narendra Modi.

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model="gpt-2")
input_text = "Can you teach me AI?"
output = pipe(input_text, max_length=100, do_sample=True)
print(output[0]['generated_text'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/BGS GEN AI/myenv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File ~/BGS GEN AI/myenv/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/gpt-2/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model="deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B", trust_remote_code=True)

input_text = "Who are you?"
output = pipe(input_text, max_length=100, do_sample=True)
print(output[0]['generated_text'])
